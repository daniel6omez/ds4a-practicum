# %% [markdown]
# # ANDRES PLAYGROUND

# %%
# %%time
import pandas as pd
import glob

path = r'annualData2014-2019/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    temp_df = pd.read_csv(filename, index_col=None, header=0)
    li.append(temp_df)

df = pd.concat(li, axis=0, ignore_index=True)
df.head(20)
# Out:
# <string>:2: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 1.39 s, sys: 73.3 ms, total: 1.46 s
# Wall time: 1.48 s
#             X         Y  OBJECTID RADICADO                   FECHA      HORA  \
# 0  -75.602726  6.219016    211279  1423828  2014/01/01 00:00:00+00  02:20:00
# 1  -75.568185  6.260009    211280  1423839  2014/01/01 00:00:00+00  12:50:00
# 2  -75.549943  6.264765    211281  1423840  2014/01/01 00:00:00+00  01:00:00
# 3  -75.607611  6.234327    211282  1423849  2014/01/01 00:00:00+00  12:37:00
# 4  -75.579685  6.299968    211283  1423890  2014/01/01 00:00:00+00  10:40:00
# 5  -75.555429  6.284499    211284  1423892  2014/01/01 00:00:00+00  04:00:00
# 6  -75.555254  6.243999    211285  1423894  2014/01/01 00:00:00+00  07:15:00
# 7  -75.554608  6.235756    211286  1423896  2014/01/01 00:00:00+00  05:00:00
# 8  -75.595777  6.257979    211287  1423897  2014/01/01 00:00:00+00  01:30:00
# ...

# %%
df.describe()
# Out:
#                    X              Y       OBJECTID            DIA  \
# count  240333.000000  240333.000000  251899.000000  251899.000000
# mean      -75.576792       6.250698  407060.003684      15.668522
# std         0.018724       0.027988  245243.193626       8.736602
# min       -75.701661       6.151932       1.000000       1.000000
# 25%       -75.586662       6.232658  234384.500000       8.000000
# 50%       -75.574753       6.250417  346018.000000      16.000000
# 75%       -75.565067       6.271445  664807.500000      23.000000
# max       -75.473437       6.368394  758669.000000      31.000000
#
#              PERIODO            MES     X_MAGNAMED    Y_MAGNAMED  \
# count  251899.000000  251899.000000  251899.000000  2.518990e+05
# mean     2016.497858       6.628601  834066.272241  1.183194e+06
# std         1.704951       3.401817    2072.292554  3.093639e+03
# min      2014.000000       1.000000  820242.740000  1.172269e+06
# ...
